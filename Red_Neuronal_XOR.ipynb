# %% [markdown]
# <a href="https://colab.research.google.com/github/diancastroherrera-dot/RedesMulticapa/blob/main/Red_Neuronal_XOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Redes Neuronales

# %%
import numpy as np

# Datos XOR
X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[0],[1],[1],[0]])

# %%
"""
Definir el modelo de red neuronal
"""
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

modelo = Sequential([#Sequencial crea la primer capa oculta de neuronas
    Dense(4, activation='relu', input_dim=2),#Máximo de 0 con x, es decir, crea UNA capa oculta, mientras más 'relu', más capas ocultas
    Dense(1, activation='sigmoid') #Capa de salida (Función de activación)
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
"""
Compilar el modelo
"""
from tensorflow.keras.optimizers import Adam

# %%
"""
Entrenar el modelo
"""
history = modelo.fit(
    X, y,
    epochs=100,
    verbose=1,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1725927641.py in <cell line: 0>()
#       2 Entrenar el modelo
#       3 """
# ----> 4 history = modelo.fit(
#       5     X, y,
#       6     epochs=100,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/trainer.py in _assert_compile_called(self, method_name)
#    1048             else:
#    1049                 msg += f"calling `{method_name}()`."
# -> 1050             raise ValueError(msg)
#    1051
#    1052     def _symbolic_build(self, iterator=None, data_batch=None):
#
# ValueError: You must call `compile()` before using the model.

# %%
"""
Gráficando la funcion de pérdida
"""
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.title('Evolución de la pérdida (Loss)')
plt.xlabel('Época')
plt.ylabel('Binary Cross-Entropy')
plt.show()

# %%
"""
Evaluar el modelo en el conjunto de prueba
"""
loss, accuracy = modelo.evaluate(X, y)
print(f'Loss: {loss}, Accuracy: {accuracy}')

# %%
"""
Predicción
"""
pred = (modelo.predict(X) > 0.5).astype(int)
for i, (inp, p) in enumerate(zip(X, pred)):
    print(f"{inp} -> {p[0]}")
